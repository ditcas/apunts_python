# %% [markdown]
# # List
#
# Collection: many values in a single "variable". For example: List, Dictionary, Tuple.
#
# - A list element can be any Python object, even another list.
# - Una list és mutable, és a dir, podem modificar-ne els elements.

# %% [markdown]
# ## Seleccionar un element de la llista - list[ ]

# %%
list1 = ["red", 24, 98.6, [5, 6]] 

print(list1[0]) # Imprimeix el primer element de la llista
print(list1[1]) # Imprimeix el segon element de la llista
print(list1[-1]) # Imprimeix l'últim element de la llista
print(f"El penúltim element de la llista és el {list1[-2]}.") # També es poden usar cadenes f en llistes
# Out:
# red
# 24
# [5, 6]
# El penúltim element de la llista és el 98.6.

# %% [markdown]
# ## Modificar un element de la llista - list[ ] =

# %%
list1 = ["red", 24, 98.6, [5, 6]] 

list1[0] = "blue" #modifico el primer element de la llista
print("La llista amb el primer element modificat:", list1)
# Out:
# La llista amb el primer element modificat: ['blue', 24, 98.6, [5, 6]]

# %% [markdown]
# ## Longitud (quantitat d'elements) d'una llista - len(list)

# %%
list1 = ["red", 24, 98.6, [5, 6]] 
print("La llista té en total", len(list1), "elements")
# Out:
# La llista té en total 4 elements

# %% [markdown]
# ## Recórrer i enumerar una llista - for item in list :

# %%
# Bucle que recórre i compta els elements de la llista

from typing import Collection


list1 = ["red", 24, 98.6, [5, 6]] 

#count = 0
#for item in list1 :
#    print("L'ítem", item, "és el número", count, "de la llista")
#    count += 1 # count = count + 1

for i, item in enumerate(list1) :
    print("L'ítem", item, "és el número", i, "de la llista")
# Out:
# L'ítem red és el número 0 de la llista
# L'ítem 24 és el número 1 de la llista
# L'ítem 98.6 és el número 2 de la llista
# L'ítem [5, 6] és el número 3 de la llista

# %% [markdown]
# ## Funció range()
#
# La funció range genera una successió de números.
#
# Per a veure la llista de números que genera, cal posar la funció list al davant.
#
# Serveix, per exemple, com a variable d'iteració per recórrer els elements d'una llista.

# %%
list1 = ["red", 24, 98.6, [5, 6]] 

print(list(range(5))) # Genera una llista de valors del 0 al 5 no inclòs
print(list(reversed(range(5))))

print(list(range(2,11,3))) # Genera una llista que comença en el 2 i avança de 3 en 3 fins arribar a 10.
print(f"Les posicions dels elements de la llista {list1} són", list(range(len(list1))))

# Bucle que genera els quadrats dels primers 10 nombres
squares = list()

for nombre in range(1,11) :
    squares.append(nombre**2)  # Mètode que afegeix elements a una llista, sempre al final.
print("Llista dels quadrats dels primers 10 nombres", squares)
# Out:
# [0, 1, 2, 3, 4]
# [4, 3, 2, 1, 0]
# [2, 5, 8]
# Les posicions dels elements de la llista ['red', 24, 98.6, [5, 6]] són [0, 1, 2, 3]
# Llista dels quadrats dels primers 10 nombres [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# ## Llistes per comprensió - [___ for ___ in ___ if ___]
#
# List comprehensions are one of the most-loved Python language features. They allow you to concisely form a new list by filtering the elements of a collection, transforming the elements passing the filter in one concise expression.
#
# They take the basic form:
# ```python
# [expr for val in collection if condition]
# ```
#
# This is equivalent to the following for loop:
# ```python
# result = []
# for val in collection:
#     if condition:
#         result.append(expr)
# ```
# The filter condition can be omitted, leaving only the expression.

# %%
squares2 = [nombre**2 for nombre in range(1,11)]
print("Llista per comprensió dels quadrats dels primers 10 nombres", squares2)

strings = ['a', 'as', 'bat', 'car', 'dove', 'python']
len2 = [x.upper() for x in strings if len(x)>2]
print("Strings en majúscula formades per més de dos caràcters:", len2)
# Out:
# Llista per comprensió dels quadrats dels primers 10 nombres [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# Strings en majúscula formades per més de dos caràcters: ['BAT', 'CAR', 'DOVE', 'PYTHON']

# %% [markdown]
# ## Concatenar llistes -  list1 + list2

# %%
lista = [1, 4, 6]
listb = [3, 5, 8]
listab = lista + listb
print("Llist a i llista b concatenades:", listab)
# Out:
# Llist a i llista b concatenades: [1, 4, 6, 3, 5, 8]

# %% [markdown]
# ## Slicing a list - list[ : ]
#
# Funciona igual que en les strings.

# %%
lista = [1, 4, 6]
print("Llista des del principi a l'element índex 2 no inclòs:", lista[:2])
# Out:
# Llista des del principi a l'element índex 2 no inclòs: [1, 4]

# %% [markdown]
# ## List library - Methods - Afegir, eliminar, ordenar, copiar.
#
# List Methods: append, count, extend, index, insert, pop, remove, reverse, sort... veure documentació.

# %%
lista = [1, 4, 6]

lista.append(12) #Afegeix element 12 al final de la llista
print("Llista a amb element 12 afegit al final", lista)

#  append multiple elements. El method extend és més eficient que concatenar.
lista.extend([8, 10, 11])

print(12 in lista) # Saber si un element està o no la llista. Retorna True o False
print(4 not in lista)

# Afegir elements en qualsevol posició
lista.insert(1, 5)
print("Llista a amb l'element 5 afegit en la posició índex 1", lista)

# insert is computationally expensive compared with append, because references to subsequent elements have to be shifted internally to make room for the new element. If you need to insert elements at both the beginning and end of a sequence, you may wish to explore collections.deque, a double-ended queue, for this purpose.

# Eliminar un element si en sabem la posició. Després no es pot accedir a l'element eliminat.
del lista[3]
print("Llista a sense el quart element", lista)

# Eliminar element de la llista i guardar-lo en una variable per poder-lo usar després
print("La llista a en aquests moments és aquesta:", lista)
pop_element = lista.pop(1) #Elimino el segon element i el guardo en la variable pop_element. Si no posem argument, elimina l'últim element per defecte.
print("Després d'eliminar el segon element la llista a és aquesta:", lista)
print(f"L'element eliminat és el {pop_element}")

# Eliminar el primer element de la llista que coincideixi amb el valor donat. Si l'element estigués repetit, i volguessim eliminar-los tots, caldria fer bucle.
fruites = ["aguacate", "meló", "síndria", "taronja", "plàtan"]
citric = "taronja"
fruites.remove(citric)
print(f"Després d'eliminar la fruita cítrica {citric}, la llista queda:", fruites)


# Ordenar valors de petit a gran, o strings en ordre alfabètic (Ojo: sempre considera les majúscules més grans que les minúsucles). Si la llista conté valors i strings barrejat dona traceback.
# El mètode SORT modifica la llista de manera permanent
listb = [3, 5, 8]
listab = lista + listb
print("La llista ab abans d'ordenar:", listab)
listab.sort() #Modifica la llista original i quedarà listab ordenada
print("Llista ab ordenada", listab)
# listab.sort(key=len) # Ordena una llista de strings per la llargada de les strings

# Si volem saber on aniria un element en una llista ordenada per tal que s'hi mantingui, i/o inserir-lo
import bisect
position = bisect.bisect(listab,2)
print(f"El valor 2 per mantenir la llista ordenada ha de situar-se en la posició {position} de la llista ab")
bisect.insort(listab, 9)
print("La llista ab amb el valor 9 insertat és:", listab)


# Si no volem modificar la llista original, només mostrar per un moment la llista ordenada, usem SORTED
print("La llista de fruites ara mateix és aquesta: ", fruites)
print("La llista ordenada de manera descendent seria aquesta: ", sorted(fruites, reverse=True)) #usem reverse per si volem ordre descendent
print("La llista de fruites després de fer un sorted segueix sent: ", fruites)

# Invertir la llista (que no vol dir ordenar)
fruites.reverse()
print("Després de fer un reverse la llista original s'inverteix i queda: ", fruites)

# Fer una còpia d'una llista
fruites_prefe = fruites[:] #Cal posar el [:] per fer una còpia en una nova llista.
fruites_prefe.append("maduixa") # Hi afegim la maduixa
print("fruites preferides:", fruites_prefe)
print("fruites", fruites) # Són dues llistes independents. Podem fer canvis a cada una per separat.
# En canvi si fem
fruites_prefe2 = fruites # fruites_prefe2 no és una llista independent, simplement li estem dient que aquesta variable apunti també a la mateixa llista de fruites. Si fem un canvi a fruites_prefe2 o a fruites, canviaran les dues llistes, perquè de fet, són la mateixa, apunten al mateix objecte.
fruites_prefe2.append("nabiu")
print("fruites", fruites)
print("fruites preferides 2", fruites_prefe2)
# Out:
# Llista a amb element 12 afegit al final [1, 4, 6, 12]
# True
# False
# Llista a amb l'element 5 afegit en la posició índex 1 [1, 5, 4, 6, 12, 8, 10, 11]
# Llista a sense el quart element [1, 5, 4, 12, 8, 10, 11]
# La llista a en aquests moments és aquesta: [1, 5, 4, 12, 8, 10, 11]
# Després d'eliminar el segon element la llista a és aquesta: [1, 4, 12, 8, 10, 11]
# L'element eliminat és el 5
# Després d'eliminar la fruita cítrica taronja, la llista queda: ['aguacate', 'meló', 'síndria', 'plàtan']
# La llista ab abans d'ordenar: [1, 4, 12, 8, 10, 11, 3, 5, 8]
# Llista ab ordenada [1, 3, 4, 5, 8, 8, 10, 11, 12]
# El valor 2 per mantenir la llista ordenada ha de situar-se en la posició 1 de la llista ab
# La llista ab amb el valor 9 insertat és: [1, 3, 4, 5, 8, 8, 9, 10, 11, 12]
# La llista de fruites ara mateix és aquesta:  ['aguacate', 'meló', 'síndria', 'plàtan']
# La llista ordenada de manera descendent seria aquesta:  ['síndria', 'plàtan', 'meló', 'aguacate']
# ...

# %% [markdown]
# ## Funcions sum, max, min

# %%
# Bucle usant lists per fer el promig dels valors introduits. 
# Si la quantitat de valors és elevada, no és tan eficient com els exemples fets en la secció de Bucles
# ja que aquí la list va necessitant memòria per emmagatzemar primer tots els valors i després fer l'operació, 
# mentre que en els altres només es necessiten 2 variables que emmagatzemen un valor que es va sobreescrivint.

llistat = list()
while True :

    numero = input("Introdueixi un número o teclegi la paraula fi per acabar: ")

    if numero == "fi" :
        break

    try : 
        numero = float(numero)
    except :
        print("Error, per favor introdueixi un valor numèric.")
        continue

    llistat.append(numero)

sumatori = sum(llistat)
quantitat = len(llistat)
mitjana = sumatori/quantitat
maxim = max(llistat)
minim = min(llistat)

print(f"La suma dels valors introduits és {sumatori} d'un total de {quantitat} números. La mitjana aritmètica és {mitjana}. El valor més gran és el {maxim} i el valor més petit és el {minim}")
# Out:
# La suma dels valors introduits és 15.0 d'un total de 3 números. La mitjana aritmètica és 5.0. El valor més gran és el 6.0 i el valor més petit és el 4.0

# %% [markdown]
# ## Funció split
#
# Genera una llista amb els elements que conformen l'objecte separats pel marcador que indiquem. Si no li posem argument, el marcador són per defecte els espais en blanc.

# %%
# Escribir un programa para abrir el archivo romeo.txt y leerlo línea por línea. Para cada línea, dividir la línea en una lista de palabras utilizando la función split. Para cada palabra, revisar si la palabra ya se encuentra previamente en la lista. Si la palabra no está en la lista, agregarla a la lista. Cuando el programa termine, ordenar e imprimir las palabras resultantes en orden alfabético.

file = open("romeo.txt","r")

lista = list()

for line in file :
    words_for_line = line.split()

    for word in words_for_line :
        if word not in lista :
            lista.append(word)

    # Manera alternativa de fer-ho sense usar l'operador "in, not in". Cal usar bucles i cal també fer cas concret de si la llista està buida. Cal usar també un chivato de False/True, en aquest cas word_exists.
    # if len(lista) == 0 : 
    #     lista.append(word)

    # word_exists = False
    # for existing_word in lista :
    #     if word == existing_word :
    #         word_exists = True
        
    # if word_exists == False :
    #     lista.append(word)

lista.sort()
print(lista)
# Out:
# ['Arise', 'But', 'It', 'Juliet', 'Who', 'already', 'and', 'breaks', 'east', 'envious', 'fair', 'grief', 'is', 'kill', 'light', 'moon', 'pale', 'sick', 'soft', 'sun', 'the', 'through', 'what', 'window', 'with', 'yonder']

# %%
# Escribir un programa para leer a través de datos de una bandeja de entrada de correo y cuando encuentres una línea que comience con “From”, dividir la línea en palabras utilizando la función split. Estamos interesados en quién envió el mensaje, lo cual es la segunda palabra en las líneas que comienzan con From. Tendrás que analizar la línea From e imprimir la segunda palabra de cada línea From, después tendrás que contar el número de líneas From(no incluir From:) e imprimir el total al final.

import sys

file = input("Indica el nom de l'arxiu: ") #mbox.txt
try :
    file = open(file,"r")
except :
    print("No s'ha pogut trobar l'arxiu:", file)
    sys.exit()

count = 0

for line in file :
    if not line.startswith("From ") : #L'exercici demana incloure només els From_ i no els From:
        continue
    count = count + 1
    words = line.split()
    print(words[1])

print("Hi ha", count, "línies a l'arxiu que comencin per la paraula From")
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# zqian@umich.edu
# cwen@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# mmmay@indiana.edu
# cwen@iupui.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# cwen@iupui.edu
# zqian@umich.edu
# cwen@iupui.edu
# ray@media.berkeley.edu
# zqian@umich.edu
# zqian@umich.edu
# zqian@umich.edu
# cwen@iupui.edu
# zqian@umich.edu
# ...

# %%
# Prova de realitzar el mateix exercici de la secció Files amb la comanda "split".

# Escribe un programa que solicite un nombre de archivo y después lea ese archivo buscando las líneas que tengan la siguiente forma:X-DSPAM-Confidence: 0.8475 **Cuando encuentres una línea que comience con “X-DSPAM-Confidence:” ponla aparte para extraer el número decimal de la línea. Cuenta esas líneas y después calcula el total acumulado de los valores de “spam-confidence”. Cuando llegues al final del archivo, imprime el valor medio de “spam confidence”.

import sys

file = input("Indica el nom de l'arxiu: ") #mbox.txt
try :
    file = open(file,"r")
except :
    print("No s'ha pogut trobar l'arxiu:", file)
    sys.exit()

count = 0
sumatori = 0

# La línea és "X-DSPAM-Confidence: 0.7002", si fem "split" per defecte separa per l'espai, i per tant transforma una string en una llista, que té en aquest cas dos elements, X-DSPAM-Confidence: i 0.7002.

for line in file :
    if not "X-DSPAM-Confidence:" in line :
        continue
    count = count + 1
    words = line.split()
    try :        
        codi = float(words[1])
    except :
        sys.exit("Error en transformar string to float")
    sumatori = sumatori + codi


print("Promig Spam Confidence", sumatori/count)
# Out:
# Promig Spam Confidence 0.8941280467445736
